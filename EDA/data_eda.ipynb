# %% [markdown]
# ### Exploring the data obtained from Glassdoor based on the job search for "Data Scientist" with an empty location. These results relate to 1,000 different job postings.

# %% [markdown]
# *Importing the cleaned salary data and required libraries for analyzing the data.*

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('salary_data_cleaned.csv')

# %%
def title_simplifier(title):
    if 'data scientist' in title.lower():
        return 'data scientist'
    elif 'data engineer' in title.lower():
        return 'data engineer'
    elif 'analyst' in title.lower():
        return 'analyst'
    elif 'machine learning' in title.lower():
        return 'machine learning engineer'
    elif 'manager' in title.lower():
        return 'manager'
    elif 'director' in title.lower():
        return 'director'
    else:
        return 'na'
    
def seniority(title):
    if 'sr' in title.lower() or 'senior' in title.lower() or 'lead' in title.lower() or 'principal' in title.lower() or 'sr.' in title.lower():
        return 'senior'
    elif 'jr' in title.lower() or 'jr.' in title.lower() or 'junior' in title.lower():
        return 'junior'
    else:
        return 'na'

# %% [markdown]
# *Adding in job titles and seniority levels to analyze the type of positions that are sought after and find a relationship with average salary level.*

# %%
df['job_simple'] = df['Job Title'].apply(title_simplifier)
df.job_simple.value_counts()
# Out:
# data scientist               576
# na                            56
# data engineer                 48
# machine learning engineer      9
# director                       9
# analyst                        7
# manager                        1
# Name: job_simple, dtype: int64

# %%
df['seniority'] = df['Job Title'].apply(seniority)
df.seniority.value_counts()
# Out:
# na        640
# senior     65
# junior      1
# Name: seniority, dtype: int64

# %% [markdown]
# *Viewing the number of available jobs by state.*

# %%
df.job_state.value_counts()
# Out:
#  CA    135
#  VA    104
#  NY     60
#  MA     51
#  MD     42
#  TX     40
#  IL     26
#  PA     20
#  OH     20
#  AZ     19
#  DC     19
#  WI     15
#  MI     13
#  UT     12
#  WA     12
#  FL     11
#  NJ     11
#  MO     11
#  AL     10
#  MN     10
#  CT      9
#  NC      9
#  GA      9
#  IN      7
#  CO      6
#  KY      5
#  TN      5
#  NE      3
#  HI      2
#  OR      2
#  NH      2
#  IA      1
#  DE      1
#  WV      1
#  NM      1
#  KS      1
#  MS      1
# Name: job_state, dtype: int64

# %% [markdown]
# *Analyzing the job description lengths.*

# %%
df['desc_len'] = df ['Job Description'].apply(lambda x: len(x))
df['desc_len']
# Out:
# 0      2962
# 1      9119
# 2      8669
# 3      2855
# 4      3559
#        ...
# 701    1718
# 702    3664
# 703    4030
# 704    2956
# 705    1930
# Name: desc_len, Length: 706, dtype: int64

# %% [markdown]
# *Converting the postings that have hourly wage to annual wage.*

# %%
# Hourly wage to annual
df['min_salary'] = df.apply(lambda x: x.min_salary*2 if x.hourly ==1 else x.min_salary, axis =1)
df['max_salary'] = df.apply(lambda x: x.max_salary*2 if x.hourly ==1 else x.max_salary, axis =1)
df[df.hourly ==1][['hourly','min_salary','max_salary']]
# Out:
#      hourly  min_salary  max_salary
# 39        1          50          56
# 278       1          26          48
# 580       1          36          68
# 581       1          36          68

# %% [markdown]
# *Cleaning up the company names and taking an overview look at the data.*

# %%
df['company_txt'] = df.company_txt.apply(lambda x: x.replace('\n', ''))
df['company_txt'] = df.company_txt.apply(lambda x: x.replace('\r', ''))
df['company_txt']
df.describe()
# Out:
#            Rating  Headquarters      Founded  Competitors      hourly  \
# count  706.000000         706.0   706.000000        706.0  706.000000
# mean     3.706516          -1.0  1795.094901         -1.0    0.005666
# std      0.788562           0.0   573.994413          0.0    0.075111
# min     -1.000000          -1.0    -1.000000         -1.0    0.000000
# 25%      3.400000          -1.0  1946.000000         -1.0    0.000000
# 50%      3.800000          -1.0  1994.000000         -1.0    0.000000
# 75%      4.100000          -1.0  2005.000000         -1.0    0.000000
# max      5.000000          -1.0  2018.000000         -1.0    1.000000
#
#        employer_provided  min_salary  max_salary  avg_salary  state_hq  ...  \
# count         706.000000  706.000000  706.000000  706.000000     706.0  ...
# mean            0.001416   79.730878  128.087819  103.771955       0.0  ...
# std             0.037635   22.465951   32.465772   27.049463       0.0  ...
# min             0.000000   12.000000   16.000000   15.500000       0.0  ...
# 25%             0.000000   64.250000  108.000000   87.000000       0.0  ...
# 50%             0.000000   78.000000  124.500000  101.250000       0.0  ...
# 75%             0.000000   92.000000  145.000000  118.375000       0.0  ...
# max             1.000000  212.000000  331.000000  271.500000       0.0  ...
#
#          scala_yn       go_yn  elm_yn     ruby_yn   csharp_yn     rust_yn  \
# count  706.000000  706.000000   706.0  706.000000  706.000000  706.000000
# mean     0.229462    0.839943     0.0    0.015581    0.113314    0.137394
# std      0.420785    0.366919     0.0    0.123934    0.317202    0.344507
# min      0.000000    0.000000     0.0    0.000000    0.000000    0.000000
# 25%      0.000000    1.000000     0.0    0.000000    0.000000    0.000000
# 50%      0.000000    1.000000     0.0    0.000000    0.000000    0.000000
# 75%      0.000000    1.000000     0.0    0.000000    0.000000    0.000000
# max      1.000000    1.000000     0.0    1.000000    1.000000    1.000000
#
#            sql_yn   matlab_yn    julia_yn     desc_len
# count  706.000000  706.000000  706.000000   706.000000
# mean     0.569405    0.089235    0.012748  3653.143059
# std      0.495511    0.285285    0.112264  1486.300042
# min      0.000000    0.000000    0.000000   478.000000
# 25%      0.000000    0.000000    0.000000  2705.250000
# 50%      1.000000    0.000000    0.000000  3525.000000
# 75%      1.000000    0.000000    0.000000  4433.250000
# max      1.000000    1.000000    1.000000  9710.000000
#
# [8 rows x 28 columns]

# %% [markdown]
# *Creating histograms to summarize company values.*

# %%
# Summarizing companies based on their rating
df.Rating.hist()

# %%
# Summarizing companies based on the average salary
df.avg_salary.hist()

# %%
# Summarizing companies based on their age
df.age.hist()

# %%
# Summarizing companies based on the job description lengths
df.desc_len.hist()

# %% [markdown]
# *Creating boxplots to visually evaluate the descriptions of maximums, minimums, median values, first quarter values, and third quarter values of the data.*

# %%
# Describing companies based on their age
df.boxplot(column = ['age'])

# %%
# Describing companies based on the average salary
df.boxplot(column = ['avg_salary'])

# %%
# Describing companies based on their ratings
df.boxplot(column = ['Rating'])

# %%
# Describing companies based on the job description lengths
df.boxplot(column = ['desc_len'])

# %% [markdown]
# *Finding a correlation between each of the categories and plotting them on a heatmap for visual analysis.*

# %%
df[['age', 'avg_salary', 'Rating', 'desc_len']].corr()
# Out:
#                  age  avg_salary    Rating  desc_len
# age         1.000000   -0.056733  0.082998  0.185145
# avg_salary -0.056733    1.000000  0.018314  0.069384
# Rating      0.082998    0.018314  1.000000 -0.019876
# desc_len    0.185145    0.069384 -0.019876  1.000000

# %%
cmap = sns.diverging_palette(220, 10, as_cmap=True)
sns.heatmap(df[['age', 'avg_salary', 'Rating', 'desc_len']].corr(), cmap=cmap, vmax=.3, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})

# %% [markdown]
# *Creating bar graphs to visually analyze the similarities between categories.*

# %%
df_cat1 = df[['Size', 'Type of ownership', 'Sector', 'Revenue', 'job_state', 'job_simple', 'seniority']]
df_cat2 = df[['Location', 'company_txt', 'Industry']]
df_cat3 = df[['python_yn',
       'rstudio_yn', 'spark_yn', 'aws_yn', 'excel_yn', 'java_yn', 'swift_yn',
       'scala_yn', 'go_yn', 'elm_yn', 'ruby_yn', 'csharp_yn', 'rust_yn',
       'sql_yn', 'matlab_yn', 'julia_yn']]

# %%
for i in df_cat1.columns:
    cat_num = df_cat1[i].value_counts()
    print("graph for %s: total = %d" % (i, len(cat_num)))
    chart = sns.barplot(x=cat_num.index, y=cat_num)
    chart.set_xticklabels(chart.get_xticklabels(), rotation=90)
    plt.show()
# Out:
# graph for Size: total = 8
# graph for Type of ownership: total = 10
# graph for Sector: total = 24
# graph for Revenue: total = 13
# graph for job_state: total = 37
# graph for job_simple: total = 7
# graph for seniority: total = 3

# %%
for i in df_cat2.columns:
    cat_num = df_cat2[i].value_counts()[:20]
    print("graph for %s: total = %d" % (i, len(cat_num)))
    chart = sns.barplot(x=cat_num.index, y=cat_num)
    chart.set_xticklabels(chart.get_xticklabels(), rotation=90)
    plt.show()
# Out:
# graph for Location: total = 20
# graph for company_txt: total = 20
# graph for Industry: total = 20

# %%
for i in df_cat3.columns:
    cat_num = df_cat3[i].value_counts()[:20]
    print("graph for %s: total = %d" % (i, len(cat_num)))
    chart = sns.barplot(x=cat_num.index, y=cat_num)
    chart.set_xticklabels(chart.get_xticklabels(), rotation=90)
    plt.show()
# Out:
# graph for python_yn: total = 2
# graph for rstudio_yn: total = 2
# graph for spark_yn: total = 2
# graph for aws_yn: total = 2
# graph for excel_yn: total = 2
# graph for java_yn: total = 2
# graph for swift_yn: total = 2
# graph for scala_yn: total = 2
# graph for go_yn: total = 2
# graph for elm_yn: total = 1
# graph for ruby_yn: total = 2
# graph for csharp_yn: total = 2
# graph for rust_yn: total = 2
# graph for sql_yn: total = 2
# graph for matlab_yn: total = 2
# graph for julia_yn: total = 2

# %% [markdown]
# *Creating pivot tables to see the average salary based on job titles and seniority levels.*

# %%
# Finding average salary for types of jobs
pd.pivot_table(df, index = 'job_simple', values = 'avg_salary')
# Out:
#                            avg_salary
# job_simple
# analyst                     87.571429
# data engineer              107.458333
# data scientist             105.955729
# director                    94.000000
# machine learning engineer  115.277778
# manager                    172.000000
# na                          78.678571

# %%
# Finding average salary for types of jobs with seniority values
pd.pivot_table(df, index = ['job_simple', 'seniority'], values = 'avg_salary')
# Out:
#                                      avg_salary
# job_simple                seniority
# analyst                   na          73.900000
#                           senior     121.750000
# data engineer             na         101.441176
#                           senior     122.071429
# data scientist            junior      60.000000
#                           na         103.522346
#                           senior     141.552632
# director                  na          94.000000
# machine learning engineer na         115.277778
# manager                   na         172.000000
# na                        na          75.988889
#                           senior      89.681818

# %%
pd.set_option('display.max_rows', None)

# %%
# Finding number of jobs based on state
pd.pivot_table(df, index = ['job_state', 'job_simple'], values = 'avg_salary', aggfunc = 'count').sort_values('job_state', ascending = True)
# Out:
#                                      avg_salary
# job_state job_simple
#  AL       data scientist                      9
#           na                                  1
#  AZ       data scientist                     13
#           director                            6
#  CA       manager                             1
#           machine learning engineer           3
#           na                                  5
#           data engineer                       7
#           analyst                             2
#           data scientist                    117
#  CO       data engineer                       2
#           data scientist                      4
#  CT       data engineer                       1
#           data scientist                      7
#           na                                  1
#  DC       data scientist                     19
#  DE       data scientist                      1
#  FL       data scientist                      9
#           na                                  2
#  GA       data scientist                      6
#           data engineer                       3
#  HI       data scientist                      2
#  IA       data engineer                       1
#  IL       analyst                             2
#           data engineer                       1
#           data scientist                     22
#           na                                  1
#  IN       data scientist                      7
#  KS       data scientist                      1
#  KY       data scientist                      5
#  MA       na                                 10
#           machine learning engineer           2
#           data engineer                       5
#           data scientist                     33
#           director                            1
#  MD       data scientist                     37
#           data engineer                       5
#  MI       director                            1
#           na                                  4
#           data engineer                       1
#           data scientist                      7
#  MN       director                            1
#           data engineer                       2
#           data scientist                      7
#  MO       data engineer                       1
#           data scientist                     10
#  MS       na                                  1
#  NC       data scientist                      5
#           na                                  4
#  NE       data scientist                      3
#  NH       data scientist                      2
#  NJ       na                                  1
#           data scientist                      8
#           analyst                             1
#           data engineer                       1
#  NM       na                                  1
#  NY       data engineer                       3
#           data scientist                     55
#           na                                  2
#  OH       analyst                             1
#           data scientist                     15
#           na                                  4
#  OR       data scientist                      2
#  PA       data scientist                     18
#           data engineer                       2
#  TN       data scientist                      4
#           na                                  1
#  TX       data engineer                       3
#           data scientist                     30
#           machine learning engineer           3
#           na                                  4
#  UT       data engineer                       1
#           data scientist                      5
#           na                                  6
#  VA       data engineer                       8
#           data scientist                     92
#           na                                  4
#  WA       data scientist                     11
#           machine learning engineer           1
#  WI       data scientist                      9
#           na                                  4
#           analyst                             1
#           data engineer                       1
#  WV       data scientist                      1

# %%
# Finding average salary by state
pd.pivot_table(df[df.job_simple == 'data scientist'], index = 'job_state', values = 'avg_salary').sort_values('avg_salary', ascending = False)
# Out:
#            avg_salary
# job_state
#  CA        126.649573
#  KY        114.500000
#  OR        112.000000
#  MA        111.757576
#  KS        111.000000
#  WA        109.409091
#  TN        109.000000
#  NY        106.900000
#  MD        105.391892
#  VA        103.576087
#  GA        102.916667
#  NC        101.500000
#  IL        101.250000
#  NJ         99.875000
#  TX         99.866667
#  OH         99.800000
#  AZ         97.538462
#  PA         95.472222
#  DC         94.552632
#  WI         94.444444
#  UT         94.000000
#  CO         93.625000
#  MI         91.428571
#  AL         88.722222
#  FL         88.333333
#  MO         88.300000
#  MN         88.071429
#  DE         86.500000
#  IN         85.071429
#  HI         82.500000
#  NH         81.000000
#  CT         76.214286
#  NE         70.000000
#  WV         62.000000

# %%
# Finding average salary based on company ratings
df_pivots = df[['Rating', 'Type of ownership', 'Industry', 'Sector', 'Revenue', 'hourly', 'employer_provided', 'python_yn', 'rstudio_yn', 'spark_yn', 'aws_yn', 'excel_yn', 'java_yn', 'swift_yn', 'scala_yn', 'go_yn', 'elm_yn', 'ruby_yn', 'csharp_yn', 'rust_yn', 'sql_yn', 'matlab_yn', 'julia_yn', 'avg_salary']]

# %%
for i in df_pivots.columns:
    print(i)
    print(pd.pivot_table(df_pivots, index = i, values = 'avg_salary').sort_values('avg_salary', ascending = False))
# Out:
# Rating
#         avg_salary
# Rating
#  2.1    151.500000
#  2.0    140.000000
#  3.6    126.553571
#  2.5    120.300000
#  4.7    116.636364
#  4.9    114.785714
#  4.6    112.578947
#  4.1    108.697368
#  3.9    108.507246
#  2.4    108.500000
#  4.0    107.042553
#  5.0    106.090909
#  3.0    105.333333
#  3.7    105.136364
# -1.0    104.450000
#  4.4    103.316667
#  2.2    102.750000
#  3.8    101.392405
#  2.8     99.700000
#  3.5     99.159091
#  2.9     99.045455
#  3.1     98.375000
#  4.3     98.333333
#  3.3     97.706897
#  3.4     97.693878
#  4.5     96.233333
#  4.2     95.772727
#  4.8     95.000000
#  3.2     94.933333
#  2.7     91.666667
#  2.6     91.083333
# Type of ownership
#                                 avg_salary
# Type of ownership
# Hospital                        132.166667
# Private Practice / Firm         115.500000
# Subsidiary or Business Segment  111.931034
# Company - Public                111.434010
# Nonprofit Organization          101.915094
# Company - Private               100.978036
# Government                       90.875000
# Unknown                          88.500000
# College / University             83.477273
# Contract                         77.500000
# Industry
#                                          avg_salary
# Industry
# Farm Support Services                    144.000000
# Insurance Agencies & Brokerages          138.500000
# TV Broadcast & Cable Networks            132.000000
# Telecommunications Services              131.812500
# Other Retail Stores                      131.500000
# Internet                                 125.130952
# Investment Banking & Asset Management    121.735294
# Video Games                              120.916667
# Oil & Gas Services                       119.666667
# Energy                                   118.000000
# Banks & Credit Unions                    117.888889
# Brokerage Services                       117.666667
# Transportation Equipment Manufacturing   116.722222
# Computer Hardware & Software             116.061644
# Education Training Services              116.000000
# Financial Analytics & Research           114.600000
# Sports & Recreation                      114.500000
# Biotech & Pharmaceuticals                110.880952
# Utilities                                109.000000
# Enterprise Software & Network Solutions  107.148649
# Lending                                  106.857143
# Building & Personnel Services            106.500000
# Wholesale                                105.833333
# Fast-Food & Quick-Service Restaurants    105.000000
# K-12 Education                           104.500000
# Aerospace & Defense                      103.866071
# Insurance Carriers                       103.722222
# Car Rental                               101.000000
# IT Services                              100.782609
# Advertising & Marketing                  100.608696
# Electrical & Electronic Manufacturing    100.250000
# Chemical Manufacturing                   100.000000
# Health Care Services & Hospitals          97.020833
# Federal Agencies                          96.500000
# Grantmaking Foundations                   96.500000
# Transportation Management                 96.000000
# Financial Transaction Processing          95.500000
# Telecommunications Manufacturing          95.500000
# Health, Beauty, & Fitness                 95.500000
# -1                                        95.033333
# Accounting                                91.250000
# Staffing & Outsourcing                    91.000000
# Consulting                                90.101852
# Express Delivery Services                 89.500000
# Consumer Products Manufacturing           89.500000
# Consumer Product Rental                   89.000000
# Research & Development                    87.909091
# Industrial Manufacturing                  85.250000
# Sporting Goods Stores                     85.000000
# Cable, Internet & Telephone Providers     84.500000
# Pet & Pet Supplies Stores                 84.000000
# Metal & Mineral Manufacturing             83.500000
# Architectural & Engineering Services      83.250000
# Vehicle Dealers                           83.000000
# Religious Organizations                   80.500000
# Colleges & Universities                   79.565217
# Grocery Stores & Supermarkets             79.000000
# Food & Beverage Manufacturing             77.833333
# Social Assistance                         72.500000
# Food Production                           70.500000
# Hotels, Motels, & Resorts                 69.500000
# Construction                              58.500000
# Sector
#                                     avg_salary
# Sector
# Media                               124.611111
# Telecommunications                  119.909091
# Oil, Gas, Energy & Utilities        114.857143
# Arts, Entertainment & Recreation    114.500000
# Finance                             114.125000
# Information Technology              111.522624
# Biotech & Pharmaceuticals           110.880952
# Agriculture & Forestry              107.250000
# Insurance                           107.200000
# Restaurants, Bars & Food Services   105.000000
# Aerospace & Defense                 103.866071
# Manufacturing                        98.906250
# Health Care                          97.020833
# Government                           96.500000
# -1                                   95.033333
# Transportation & Logistics           92.750000
# Consumer Services                    92.250000
# Business Services                    92.112500
# Retail                               91.638889
# Accounting & Legal                   91.250000
# Non-Profit                           86.500000
# Education                            85.660714
# Travel & Tourism                     85.250000
# Construction, Repair & Maintenance   58.500000
# Revenue
#                                   avg_salary
# Revenue
# $10+ billion (USD)                113.067708
# $25 to $50 million (USD)          109.642857
# Unknown / Non-Applicable          109.151852
# $2 to $5 billion (USD)            105.833333
# $1 to $2 billion (USD)            104.625000
# $5 to $10 billion (USD)           104.428571
# $100 to $500 million (USD)        100.702128
# Less than $1 million (USD)         98.564516
# $50 to $100 million (USD)          98.131579
# $1 to $5 million (USD)             97.194444
# $5 to $10 million (USD)            96.543478
# $500 million to $1 billion (USD)   96.226190
# $10 to $25 million (USD)           90.612069
# hourly
#         avg_salary
# hourly
# 0       104.225071
# 1        24.250000
# employer_provided
#                    avg_salary
# employer_provided
# 0                   103.88156
# 1                    26.50000
# python_yn
#            avg_salary
# python_yn
# 1          106.089391
# 0           97.784264
# rstudio_yn
#             avg_salary
# rstudio_yn
# 1           104.118214
# 0           102.307407
# spark_yn
#           avg_salary
# spark_yn
# 1         110.005747
# 0         101.733083
# aws_yn
#         avg_salary
# aws_yn
# 1       110.725904
# 0       101.634259
# excel_yn
#           avg_salary
# excel_yn
# 0         104.748148
# 1         102.458472
# java_yn
#          avg_salary
# java_yn
# 1        104.425466
# 0        103.578899
# swift_yn
#           avg_salary
# swift_yn
# 0         103.792199
# 1          89.500000
# scala_yn
#           avg_salary
# scala_yn
# 1         106.459877
# 0         102.971507
# go_yn
#        avg_salary
# go_yn
# 1      105.162732
# 0       96.473451
# elm_yn
#         avg_salary
# elm_yn
# 0       103.771955
# ruby_yn
#          avg_salary
# ruby_yn
# 0        103.980576
# 1         90.590909
# csharp_yn
#            avg_salary
# csharp_yn
# 1          104.850000
# 0          103.634185
# rust_yn
#          avg_salary
# rust_yn
# 0        103.824302
# 1        103.443299
# sql_yn
#         avg_salary
# sql_yn
# 1       107.328358
# 0        99.069079
# matlab_yn
#            avg_salary
# matlab_yn
# 0          103.846812
# 1          103.007937
# julia_yn
#           avg_salary
# julia_yn
# 0         103.801291
# 1         101.500000
# avg_salary
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-30-b07eef0360cb> in <module>
#       1 for i in df_pivots.columns:
#       2     print(i)
# ----> 3     print(pd.pivot_table(df_pivots, index = i, values = 'avg_salary').sort_values('avg_salary', ascending = False))
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\reshape\pivot.py in pivot_table(data, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name, observed)
#      98         values = list(values)
#      99
# --> 100     grouped = data.groupby(keys, observed=observed)
#     101     agged = grouped.agg(aggfunc)
#     102     if dropna and isinstance(agged, ABCDataFrame) and len(agged.columns):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed)
#    5799         axis = self._get_axis_number(axis)
#    5800
# -> 5801         return groupby_generic.DataFrameGroupBy(
#    5802             obj=self,
#    5803             keys=by,
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in __init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, squeeze, observed, mutated)
#     401             from pandas.core.groupby.grouper import get_grouper
#     402
# --> 403             grouper, exclusions, obj = get_grouper(
#     404                 obj,
#     405                 keys,
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\groupby\grouper.py in get_grouper(obj, key, axis, level, sort, observed, mutated, validate)
#     615         # allow us to passing the actual Grouping as the gpr
#     616         ping = (
# --> 617             Grouping(
#     618                 group_axis,
#     619                 gpr,
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\groupby\grouper.py in __init__(self, index, grouper, obj, name, level, sort, observed, in_axis)
#     343                 if getattr(self.grouper, "ndim", 1) != 1:
#     344                     t = self.name or str(type(self.grouper))
# --> 345                     raise ValueError(f"Grouper for '{t}' not 1-dimensional")
#     346                 self.grouper = self.index.map(self.grouper)
#     347                 if not (
#
# ValueError: Grouper for 'avg_salary' not 1-dimensional

# %%
# Companies by revenue that want python based on increase in average salary
pd.pivot_table(df_pivots, index = 'Revenue', columns = 'python_yn', values = 'avg_salary', aggfunc = 'count')

# %% [markdown]
# *Creating a word cloud to visually observe the words in each job description*

# %%
from wordcloud import WordCloud, ImageColorGenerator, STOPWORDS
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

# %%
words = " ".join(df['Job Description'])

def punctuation_stop(text):
    """remove punctuation and stop words"""
    filtered = []
    stop_words = set(stopwords.words('english'))
    word_tokens = word_tokenize(text)
    for w in word_tokens:
        if w not in stop_words and w.isalpha():
            filtered.append(w.lower())
    return filtered


words_filtered = punctuation_stop(words)

text = " ".join([ele for ele in words_filtered])

wc= WordCloud(background_color="white", random_state=1,stopwords=STOPWORDS, max_words = 500, width =1920, height = 1080)
wc.generate(text)

plt.figure(figsize=[10,10])
plt.imshow(wc, interpolation="bilinear")
plt.axis('off')
plt.show()

# %%
df.to_csv('eda_data.csv')
